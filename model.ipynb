# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('./data/train.csv', index_col=0)
train
# Out:
#                date  store_nbr                      family     sales  \
# id
# 0        2013-01-01          1                  AUTOMOTIVE     0.000
# 1        2013-01-01          1                   BABY CARE     0.000
# 2        2013-01-01          1                      BEAUTY     0.000
# 3        2013-01-01          1                   BEVERAGES     0.000
# 4        2013-01-01          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# id
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# ...

# %%
fig, ax = plt.subplots(figsize=(10,20))
sales = train.groupby('family').sum().sort_values(by='sales').sales
plt.bar(sales.index, sales)
ax.yaxis.set_major_formatter(formatter = lambda x,y: f'${x/1000000:.1f}M')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\803026583.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales = train.groupby('family').sum().sort_values(by='sales').sales

# %%
fig, ax = plt.subplots(figsize=(10,20))
promotional_sales = train.groupby('family').sum().sort_values(by='onpromotion').onpromotion
plt.bar(promotional_sales.index, promotional_sales)
ax.yaxis.set_major_formatter(formatter = lambda x,y: f'${x/1000000:.1f}M')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\3369230456.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   promotional_sales = train.groupby('family').sum().sort_values(by='onpromotion').onpromotion

# %%
train['total_sales'] = train.sales + train.onpromotion
train
# Out:
#                date  store_nbr                      family     sales  \
# id
# 0        2013-01-01          1                  AUTOMOTIVE     0.000
# 1        2013-01-01          1                   BABY CARE     0.000
# 2        2013-01-01          1                      BEAUTY     0.000
# 3        2013-01-01          1                   BEVERAGES     0.000
# 4        2013-01-01          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  total_sales
# id
# 0                  0        0.000
# 1                  0        0.000
# ...

# %%
fig, ax = plt.subplots(figsize=(10,20))
store_sales = train.groupby('store_nbr').sum()['total_sales']
plt.scatter(store_sales.index, store_sales)
ax.yaxis.set_major_formatter(formatter = lambda x,y: f'${x/1000000:.1f}M')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\3140524798.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   store_sales = train.groupby('store_nbr').sum()['total_sales']

# %%
train.date = pd.to_datetime(train.date)
train
# Out:
#               date  store_nbr                      family     sales  \
# id
# 0       2013-01-01          1                  AUTOMOTIVE     0.000
# 1       2013-01-01          1                   BABY CARE     0.000
# 2       2013-01-01          1                      BEAUTY     0.000
# 3       2013-01-01          1                   BEVERAGES     0.000
# 4       2013-01-01          1                       BOOKS     0.000
# ...            ...        ...                         ...       ...
# 3000883 2017-08-15          9                     POULTRY   438.133
# 3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  total_sales
# id
# 0                  0        0.000
# 1                  0        0.000
# 2                  0        0.000
# ...

# %%
train['timestamp'] = train.date.apply(lambda x:x.timestamp())
train
# Out:
#               date  store_nbr                      family     sales  \
# id
# 0       2013-01-01          1                  AUTOMOTIVE     0.000
# 1       2013-01-01          1                   BABY CARE     0.000
# 2       2013-01-01          1                      BEAUTY     0.000
# 3       2013-01-01          1                   BEVERAGES     0.000
# 4       2013-01-01          1                       BOOKS     0.000
# ...            ...        ...                         ...       ...
# 3000883 2017-08-15          9                     POULTRY   438.133
# 3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  total_sales     timestamp
# id
# 0                  0        0.000  1.356998e+09
# ...

# %%
family = pd.Categorical(train.family)
family.categories
# Out:
# Index(['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS',
#        'BREAD/BAKERY', 'CELEBRATION', 'CLEANING', 'DAIRY', 'DELI', 'EGGS',
#        'FROZEN FOODS', 'GROCERY I', 'GROCERY II', 'HARDWARE',
#        'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES',
#        'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE',
#        'LIQUOR,WINE,BEER', 'MAGAZINES', 'MEATS', 'PERSONAL CARE',
#        'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'POULTRY', 'PREPARED FOODS',
#        'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES', 'SEAFOOD'],
#       dtype='object')

# %%
train.family = family.codes
train
# Out:
#               date  store_nbr  family     sales  onpromotion  total_sales  \
# id
# 0       2013-01-01          1       0     0.000            0        0.000
# 1       2013-01-01          1       1     0.000            0        0.000
# 2       2013-01-01          1       2     0.000            0        0.000
# 3       2013-01-01          1       3     0.000            0        0.000
# 4       2013-01-01          1       4     0.000            0        0.000
# ...            ...        ...     ...       ...          ...          ...
# 3000883 2017-08-15          9      28   438.133            0      438.133
# 3000884 2017-08-15          9      29   154.553            1      155.553
# 3000885 2017-08-15          9      30  2419.729          148     2567.729
# 3000886 2017-08-15          9      31   121.000            8      129.000
# 3000887 2017-08-15          9      32    16.000            0       16.000
#
#             timestamp
# id
# 0        1.356998e+09
# 1        1.356998e+09
# ...

# %%
sns.heatmap(train.corr(), annot=True)
plt.show()
# Out:
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\1157722060.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(), annot=True)

# %%
temp = train.groupby(['date','family']).sum().reset_index()
temp
# Out:
#             date  family  store_nbr          sales  onpromotion  \
# 0     2013-01-01       0       1485       0.000000            0
# 1     2013-01-01       1       1485       0.000000            0
# 2     2013-01-01       2       1485       2.000000            0
# 3     2013-01-01       3       1485     810.000000            0
# 4     2013-01-01       4       1485       0.000000            0
# ...          ...     ...        ...            ...          ...
# 55567 2017-08-15      28       1485   17586.709986            6
# 55568 2017-08-15      29       1485    4641.522980            9
# 55569 2017-08-15      30       1485  125108.971000         3169
# 55570 2017-08-15      31       1485    2530.000000          148
# 55571 2017-08-15      32       1485     970.177005            0
#
#          total_sales     timestamp
# 0           0.000000  7.327791e+10
# 1           0.000000  7.327791e+10
# 2           2.000000  7.327791e+10
# 3         810.000000  7.327791e+10
# ...

# %%
plt.figure(figsize=(45,30))
sns.lineplot(data = temp, x = 'date', y='total_sales',hue='family',legend=True)
plt.show()

# %%
data = train.groupby('date').sum()
data
# Out:
#             store_nbr  family          sales  onpromotion    total_sales  \
# date
# 2013-01-01      49005   28512    2511.618999            0    2511.618999
# 2013-01-02      49005   28512  496092.417944            0  496092.417944
# 2013-01-03      49005   28512  361461.231124            0  361461.231124
# 2013-01-04      49005   28512  354459.677093            0  354459.677093
# 2013-01-05      49005   28512  477350.121229            0  477350.121229
# ...               ...     ...            ...          ...            ...
# 2017-08-11      49005   28512  826373.722022        14179  840552.722022
# 2017-08-12      49005   28512  792630.535079         8312  800942.535079
# 2017-08-13      49005   28512  865639.677471         9283  874922.677471
# 2017-08-14      49005   28512  760922.406081         8043  768965.406081
# 2017-08-15      49005   28512  762661.935939        10605  773266.935939
#
#                timestamp
# date
# 2013-01-01  2.418171e+12
# 2013-01-02  2.418325e+12
# ...

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Assuming your time series data is stored in a Pandas DataFrame or Series called 'data'
# 'data' should have a column representing the time index and another column representing the values

# Calculate autocorrelation using statsmodels
acf_values = sm.tsa.acf(data.sales, nlags=100, fft=True)

# Plot the autocorrelation values
plt.figure(figsize=(10, 4))
plt.stem(range(len(acf_values)), acf_values)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function')
plt.show()

# %%
print(sm.tsa.acf(data, nlags=len(data)-1, fft=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 print(sm.tsa.acf(data, nlags=len(data)-1, fft=True))
#
# File ~\Anaconda3\envs\first_pytorch_solution\lib\site-packages\statsmodels\tsa\stattools.py:674, in acf(x, adjusted, nlags, qstat, fft, alpha, bartlett_confint, missing)
#     670 alpha = float_like(alpha, "alpha", optional=True)
#     671 missing = string_like(
#     672     missing, "missing", options=("none", "raise", "conservative", "drop")
#     673 )
# --> 674 x = array_like(x, "x")
#     675 # TODO: should this shrink for missing="drop" and NaNs in x?
#     676 nobs = x.shape[0]
#
# File ~\Anaconda3\envs\first_pytorch_solution\lib\site-packages\statsmodels\tools\validation\validation.py:147, in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     145     if arr.ndim != ndim:
# ...

# %%
lag = 7

# %%
features = data[['timestamp', 'sales']]
features
# Out:
#                timestamp          sales
# date
# 2013-01-01  2.418171e+12    2511.618999
# 2013-01-02  2.418325e+12  496092.417944
# 2013-01-03  2.418479e+12  361461.231124
# 2013-01-04  2.418633e+12  354459.677093
# 2013-01-05  2.418787e+12  477350.121229
# ...                  ...            ...
# 2017-08-11  2.677294e+12  826373.722022
# 2017-08-12  2.677448e+12  792630.535079
# 2017-08-13  2.677602e+12  865639.677471
# 2017-08-14  2.677756e+12  760922.406081
# 2017-08-15  2.677910e+12  762661.935939
#
# [1684 rows x 2 columns]

# %%
mean_timestamp = features.timestamp.mean()
std_timestamp = features.timestamp.std()

# %%
standard_timestamp = features['timestamp'].apply(lambda x: (x-mean_timestamp)/std_timestamp)
standard_timestamp
# Out:
# date
# 2013-01-01   -1.729630
# 2013-01-02   -1.727579
# 2013-01-03   -1.725528
# 2013-01-04   -1.723478
# 2013-01-05   -1.721427
#                 ...
# 2017-08-11    1.722033
# 2017-08-12    1.724084
# 2017-08-13    1.726135
# 2017-08-14    1.728186
# 2017-08-15    1.730237
# Name: timestamp, Length: 1684, dtype: float64

# %%
mean_sales = data['sales'].mean()
std_sales = data['sales'].std()

# %%
standard_sales = data['sales'].apply(lambda x:(x-mean_sales)/std_sales)
standard_sales
# Out:
# date
# 2013-01-01   -2.709117
# 2013-01-02   -0.603489
# 2013-01-03   -1.177829
# 2013-01-04   -1.207698
# 2013-01-05   -0.683444
#                 ...
# 2017-08-11    0.805500
# 2017-08-12    0.661550
# 2017-08-13    0.973009
# 2017-08-14    0.526283
# 2017-08-15    0.533703
# Name: sales, Length: 1684, dtype: float64

# %%
import pickle
pickle.dump([mean_sales, std_sales, mean_timestamp, std_timestamp], open('standard_vals.pkl','wb'))

# %%
features.timestamp = standard_timestamp
features.sales = standard_sales
features
# Out:
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\263455831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.timestamp = standard_timestamp
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\263455831.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.sales = standard_sales
#             timestamp     sales
# date
# 2013-01-01  -1.729630 -2.709117
# 2013-01-02  -1.727579 -0.603489
# 2013-01-03  -1.725528 -1.177829
# 2013-01-04  -1.723478 -1.207698
# ...

# %%
import numpy as np
from scipy import stats

def detect_outliers_zscore(data, threshold=3):
    z_scores = np.abs(stats.zscore(data))
    outlier_indices = np.where(z_scores > threshold)[0]
    return outlier_indices

outlier_indices = detect_outliers_zscore(features['sales'], threshold=2.5)
print("Outlier indices:", outlier_indices)
# Out:
# Outlier indices: [   0  364  728 1004 1092 1094 1185 1199 1200 1213 1367 1430 1444 1449
#  1450 1457 1458 1547 1577 1583 1611 1639]

# %%
features['sales'][outlier_indices] = 0
# Out:
# C:\Users\zulno\AppData\Local\Temp\ipykernel_22860\3737072116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['sales'][outlier_indices] = 0

# %%
targets = features[['sales']].iloc[lag:]
targets
# Out:
#                sales
# date
# 2013-01-08 -1.361752
# 2013-01-09 -1.429228
# 2013-01-10 -1.615008
# 2013-01-11 -1.483803
# 2013-01-12 -0.999522
# ...              ...
# 2017-08-11  0.805500
# 2017-08-12  0.661550
# 2017-08-13  0.973009
# 2017-08-14  0.526283
# 2017-08-15  0.533703
#
# [1677 rows x 1 columns]

# %%
inputs = np.asarray([features[['timestamp','sales']].iloc[x:x+lag].values for x in range(0,features.shape[0]-lag)])
inputs.shape
# Out:
# (1677, 7, 2)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,  y_train, y_test = train_test_split(inputs, targets, test_size=.2,random_state=1234)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
model = keras.Sequential([
    layers.InputLayer((7,2)),
    layers.Dense(16, activation='elu'),
    layers.LSTM(32,dropout=.5, recurrent_dropout=.5, return_sequences=True),
    layers.LSTM(64, dropout=.5, recurrent_dropout=.5),
    layers.Dense(128, activation='elu'),
    layers.Dropout(.2),
    layers.Dense(64, activation='elu'),
    layers.Dropout(.2),
    layers.Dense(32, activation='elu'),
    layers.Dense(1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 7, 16)             48
#
#  lstm (LSTM)                 (None, 7, 32)             6272
#
#  lstm_1 (LSTM)               (None, 64)                24832
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# ...
# Total params: 49,841
# Trainable params: 49,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam',loss='mse',metrics=['mae','mape'])

# %%
history = model.fit(x_train, y_train, 1000,500,1)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 5s 43ms/step - loss: 0.6972 - mae: 0.6674 - mape: 1358066.5000
# Epoch 2/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4361 - mae: 0.5240 - mape: 4174625.0000
# Epoch 3/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4075 - mae: 0.5096 - mape: 7213151.5000
# Epoch 4/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4248 - mae: 0.5190 - mape: 8166973.5000
# Epoch 5/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3854 - mae: 0.4959 - mape: 8035576.0000
# Epoch 6/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3724 - mae: 0.4864 - mape: 5503966.0000
# Epoch 7/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3843 - mae: 0.4988 - mape: 4929031.0000
# Epoch 8/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3946 - mae: 0.5038 - mape: 5181428.0000
# Epoch 9/500
# ...

# %%
predictions = model.predict(x_test)
predictions
# Out:
# 11/11 [==============================] - 1s 3ms/step
# array([[ 1.0684428 ],
#        [-0.9070302 ],
#        [-0.07945107],
#        [ 0.3094511 ],
#        [-1.3862672 ],
#        [ 1.3232126 ],
#        [ 1.0228337 ],
#        [-0.2384253 ],
#        [ 0.5892494 ],
#        [ 0.08745982],
#        [ 1.6514558 ],
#        [-0.996364  ],
#        [ 0.03185818],
#        [-0.86013734],
#        [ 0.9232515 ],
#        [ 1.5693039 ],
#        [ 0.5452306 ],
#        [ 1.418119  ],
#        [ 0.6762825 ],
#        [ 0.6412296 ],
#        [-0.4788735 ],
#        [-0.9981226 ],
#        [ 1.4894853 ],
#        [-1.3788273 ],
#        [ 1.2004502 ],
#        [-1.2868009 ],
#        [ 1.4493382 ],
#        [-0.5988959 ],
#        [-0.7930893 ],
#        [ 0.9333769 ],
#        [ 0.52323496],
#        [-0.7209672 ],
#        [ 0.25276297],
#        [-0.2087786 ],
#        [ 0.39863104],
#        [-0.02078094],
#        [-0.6024394 ],
#        [ 0.04394111],
#        [ 0.33501264],
# ...

# %%
preds = (predictions*std_sales) + mean_sales
actual = (y_test * std_sales) + mean_sales

# %%
plt.figure(figsize=(20,3))
plt.plot(list(range(len(predictions))),preds,c='red', label='preds')
plt.plot(list(range(len(predictions))),actual, alpha=0.5, label='actual')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
from sklearn.metrics import r2_score

r2_score(actual, preds), r2_score(y_test, predictions)
# Out:
# (0.8079137259546543, 0.8079137257082095)

# %%
num_predictions = 20
temp = features.iloc[-7:]
date_range = pd.date_range(temp.index[-1],periods=num_predictions+1,freq='D')
for i in range(num_predictions):
    time_diff = temp['timestamp'][2] - temp['timestamp'][1]
    prediction = float(model.predict(np.array([temp.iloc[-7:].values]), verbose=0).squeeze())
    pred = pd.DataFrame({'timestamp':float(temp.timestamp[-1]+time_diff),'sales':prediction}, index = [date_range[i+1]])
    temp = pd.concat([temp,pred],axis=0)

# %%
plt.figure(figsize=(15,5))
plt.plot(features['sales'][-365:], c='green',label='orignal')
plt.plot(temp['sales'], c='red', label='predicted',alpha=.5)
plt.legend(bbox_to_anchor=(1,1))
plt.show()
